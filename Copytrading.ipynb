# %%
import sqlite3 
import pandas as pd 
import requests
import json  
from datetime import datetime
import secrets
import telegram #pip install python-telegram-bot --upgrade
import time
import math

pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', 500) 
pd.set_option('display.max_rows', 500) 

def connect_create_table(name_db='db.db'):
    conn = sqlite3.connect(name_db)  # You can create a new database by changing the name within the quotes
    c = conn.cursor() # The database will be saved in the location where your 'py' file is saved

    # Create table - CLIENTS
    c.execute('''CREATE TABLE if not exists POSITIONS
                 ([id] INTEGER PRIMARY KEY,
                 [date] DATETIME,
                 [encryptedUid] TEXT,
                 [nick] TEXT,
                 [symbol] TEXT,
                 [status] TEXT,
                 [entryPrice] FLOAT,
                 [markPrice] FLOAT,
                 [pnl] FLOAT,
                 [roe] FLOAT,
                 [amount] FLOAT,
                 [amount_usd] FLOAT,
                 [updateTimeStamp] TEXT,
                 [request_id] INT
                 )''')
    conn.commit()

connect_create_table()

# %%
def human_format(num):
    num = float(num)
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.2f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

# %%
def insert_in_table(trader_info, request_id, vector, status):
    encryptedUid = trader_info[0]
    nick         = trader_info[1]
    
    try:
        sqliteConnection = sqlite3.connect('db.db')
        cursor = sqliteConnection.cursor()
        
        symbol      = vector[0]
        entryPrice  = vector[1]
        markPrice   = vector[2]
        pnl         = vector[3]
        row         = vector[4]
        try: amount = float(vector[5])
        except: amount = 0
        amount_usd  = round(markPrice * amount,0)
        updateTimestamp = time.time()
        date        = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        # Need to add more info of student (such as the txns)
        sqlite_insert_with_param = """INSERT INTO POSITIONS 
                          (date, encryptedUid, nick, symbol, status, entryPrice, markPrice, pnl, roe, amount, amount_usd, updateTimeStamp, request_id) 
                          VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?,?,?);"""

        data_tuple = (date, encryptedUid, nick, symbol, status, entryPrice, markPrice, pnl, row, amount, amount_usd, updateTimestamp,request_id) 
        cursor.execute(sqlite_insert_with_param, data_tuple)
        sqliteConnection.commit()

        cursor.close()

    except sqlite3.Error as error:
        print("Failed to insert Python variable into sqlite table", error)
    finally:
        if sqliteConnection:
            sqliteConnection.close()

# %%
def do_query(db="db.db", query="SELECT * FROM POSITIONS"):    
    con = sqlite3.connect(db)
    df = pd.read_sql_query(query, con)
    
    return df

# %%
def get_positions(trader):
    endpoint = "https://www.binance.com/bapi/futures/v1/public/future/leaderboard/getOtherPosition"
    params   =  {"encryptedUid":trader,  "tradeType":"PERPETUAL"}
    headers  =  {"content-type":"application/json;charset=UTF-8"}
    response = requests.post(endpoint, json=params, headers=headers) #Add proxies = proxyDict # Attention to JSON = PARAMS
    result   = response.json()
    
    return result

# %%
def send_message(text, chat_id = "-1001455341077"):
    my_bot  = telegram.Bot("814569733:AAGmMk_P4p8EdLkj-fj2fVziyByxHIcJpm0")
    my_bot.send_message(chat_id=chat_id, text=text, parse_mode = "Markdown")

# %%
def send_message_discord(text):
    #Webhook of my channel. Click on edit channel --> Webhooks --> Creates webhook
    webhook = "https://discord.com/api/webhooks/892399337731133500/_IE9zchjLp3lRrImBt8sp_YgrI8A9Kan1Vc6wv7eY7vvkVNEAGF-YkVkiUF4pKxT5J3R"
    data    = {"content": text}
    response = requests.post(webhook, json=data)

# %%
def create_message(trader, row, trader_max_size):

    if row["difference"] > 0:
        trade_type = "BUY"
    else:
        trade_type = "SELL" 
    
    status           = str(row["status_new"])
    new_position     = round(row["amount_new"],4)
    old_position     = round(row["amount_old"],4)
    price            = str(round(row["markPrice_old"],4))
    difference       = str(abs(row["difference"]))
    symbol           = str(row["symbol"])
    date             = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
    amount_usd_new       = row["amount_usd_new"]
    amount_usd_old       = row["amount_usd_old"]
    new_position_percent = str(round(100* amount_usd_new / trader_max_size,3))
    old_position_percent     = str(round(100* amount_usd_old / trader_max_size,3))
    delta_percent    = str(round(abs(float(new_position_percent) - float(old_position_percent)),3))
    
    message =  "💰" + trader + " " + date + "\nPosition change from " + str(old_position) + symbol + " to " + str(new_position) + symbol + ".\n" + trade_type + " " + difference + symbol + " at " + price + "$" + "\nTrade went from " + old_position_percent + "% to "+ new_position_percent +"% (" + trade_type + " " + delta_percent + "%)\nStatus:" + status 
    return message

# %%
def message_logic(row, trader_dict, trader_max_size):
    if row["status_old"] == "OPEN":
        if row["difference"] != 0:   
            if   trader_dict == "TraderT":      chat_id = -542063577
            elif trader_dict == "ClickHereNow": chat_id = -591308509
            else:   chat_id = -530891051    
            message = create_message(trader_dict, row, trader_max_size)

            try: 
                send_message(message, chat_id)
                print(message)
            except: print("Too many messages")
            if trader_dict in ["TraderT","ADnefina"] : send_message_discord(message)
            time.sleep(2)

# %%
def get_positions_db(two_ids):
    # Get last update from trader.             
    this_id, last_id = two_ids["request_id"][0], two_ids["request_id"][1]

    # Get all the positions with that request_id
    new_positions   = do_query(query=f"SELECT * FROM POSITIONS WHERE request_id = '{this_id}'")
    old_positions   = do_query(query=f"SELECT * FROM POSITIONS WHERE request_id = '{last_id}'")

    # Compare the previous position with the new one, pair by pair
    both               = old_positions.merge(new_positions, "outer", on ="symbol", suffixes=('_old', '_new')).fillna(0) #Filling nas (if previous or new position is na, is because is not present, hence 0)
    both["difference"] = round(both["amount_new"] - both["amount_old"],4)
    print(both[["symbol","amount_old","amount_new","difference", "amount_usd_new"]])
    
    return both

# %%
def get_trader_max_size(trader,tol = 0.20):
    start = time.time()
    trades        = do_query(query=f"select amount_usd, request_id from positions where encryptedUid = '{trader}'")
    trades["amount_usd"]    = abs(trades["amount_usd"])
    sum_positions = trades.groupby(['request_id'])["amount_usd"].sum()
    position_max  = sum_positions.max()
    trader_max_size = position_max*(1+tol)
    print("time for getting trader max size:", round( time.time() - start,5))
    return trader_max_size

# %%
names    = {"CCF3E0CB0AAD54D9D6B4CEC5E3E741D2":"TraderT", 
            "49A7275656A7ABF56830126ACC619FEB":"ADnefina", 
            "A532C4316C00206168F795EDFBB3E164":"ClickHereNow", 
            "D3AFE978B3F0CD58489BC27B35906769":"CheerWindCard",
            "FB23E1A8B7E2944FAAEC6219BBDF8243":"BananaMan1", 
            "F318AE1B1BB3AEF4EDBD36E5AE250CD1":"BigPiePlayer", 
            "2F9D01E80429F97670415A5A5DDD9405":"CryptoPinoy",
            "95ACEF9493428B28CCADDA38A2127859":"ChurchChalkUnder",
            "382066A3597798ED9F69FECBCABAA00D":"911korn",
            "15A34DAA83C4B2D7F3A4BBAB4D2FECCA":"BakeAlsoShare",
            "3E478F9133714216B608E95B4ACF1FA3":"SABSAB",
            "B936AEC059917C5A730D45922A9F4334":"GeboyMujaer",
            "8D27A8FA0C0A726CF01A7D11E0095577":"Nothingness",
            "C6EC5B8B2D08F5748A1D8D3D849023A3":"GetSwifty",
            "191792DA7B3EEB10DAF1D51B6926F2E1":"Mikkiko",}

#names = {"A532C4316C00206168F795EDFBB3E164":"ClickHereNow"}

traders  = list(names.keys())
keys     = ["symbol", "entryPrice", "markPrice", "pnl", "roe", "amount"]

while True:
    start_trader = time.time()
    for trader in traders:
        print(" ")
        print("______________________", names[trader], "______________________")
        trader_info = [trader, names[trader]]    # Write the name of the trader
        trader_max_size = get_trader_max_size(trader)
        
        # Download data
        try:
            position_array   = get_positions(trader)     # Get the current position of the trader
            positions        = position_array["data"]["otherPositionRetList"]
            count = do_query(query="SELECT COUNT(*) as count FROM positions")["count"][0]
            if count > 0: request_id  = int(do_query(query="select MAX(id) as id from positions")["id"][0])
            else:         request_id = 0

        except:
            print(f"Couldn't download position for {names[trader]}")
            continue #This is useful not to mix stuff between positions and no positions        
        
        # Insert in the database what we downloaded
        if not positions:
            print(f"No positions for {names[trader]}, but still save.")
            empty    = [0,0,0,0,0,0] # Need to get the timestamp right!
            insert_in_table(trader_info, request_id, empty, "CLOSE")

        if positions:
            for i in range(len(positions)):
                row = pd.DataFrame(positions).loc[i]
                vector = [row["symbol"], row["entryPrice"], row["markPrice"], row["pnl"], row["roe"], row["amount"]]
                status = "CLOSED" if row["amount"] == 0 else "OPEN"
                insert_in_table(trader_info, request_id, vector, status)
        
        # Get last updates
        two_ids = do_query(query=f"select distinct(request_id) from POSITIONS where encryptedUid = '{trader}' order by request_id desc limit 2")
        
        if len(two_ids)>=2: # if the trader is in the database, check the delta
            both = get_positions_db(two_ids)

            for i in range(len(both)):
                row = both.loc[i]
                message_logic(row, names[trader], trader_max_size)
        
            time.sleep(2)
        
    print("####################################################################")
    print("Time for one cycle of traders:", round( time.time() - start_trader,2))
    print("####################################################################")
# Out:
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.0101
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       175647.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       492556.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.0147
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7784233.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01439
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1177090.00
# 1        ADAUSDT   -44457.00   -40406.00     4051.00       -90126.00
# 2        BNBUSDT     -130.50     -128.53        1.97       -53502.00
# 3        ETCUSDT      252.10      252.10        0.00        12923.00
# 4        ETHUSDT     -326.99     -301.01       25.98      -988872.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91572.00
# 6        TRXUSDT   122562.00   245127.00   122565.00        22966.00
# 7        RLCUSDT    84955.80    84955.80        0.00       315237.00
# 8        XLMUSDT    52816.00    69032.00    16216.00        20540.00
# 9        ADABUSD    48523.00    48523.00        0.00       108303.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       303090.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       122950.00
# 13       EOSUSDT    -8446.40    -9825.30    -1378.90       -41659.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       161623.00
# 15      NEARUSDT    15178.00    15178.00        0.00       116055.00
# 16       SOLBUSD      810.00      810.00        0.00       127718.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107014.00
# 18       ETHBUSD      362.09      362.09        0.00      1190250.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1155392.00
# 20       FILUSDT     1064.50     1064.50        0.00        74426.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -123917.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -112346.00
# 23       BTCUSDT      -29.30       -5.92       23.39      -282249.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115538.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       110818.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178413.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -653764.00
# 💰ClickHereNow 2021-10-02 00:14:49
# Position change from -44457.0ADAUSDT to -40406.0ADAUSDT.
# BUY 4051.0ADAUSDT at 2.2299$
# Trade went from -0.864% to -0.786% (BUY 0.078%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:14:52
# Position change from -130.5BNBUSDT to -128.53BNBUSDT.
# BUY 1.97BNBUSDT at 416.4802$
# Trade went from -0.474% to -0.466% (BUY 0.008%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:14:54
# Position change from -326.994ETHUSDT to -301.011ETHUSDT.
# BUY 25.983ETHUSDT at 3281.732$
# Trade went from -9.356% to -8.622% (BUY 0.734%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:14:56
# Position change from 122562.0TRXUSDT to 245127.0TRXUSDT.
# BUY 122565.0TRXUSDT at 0.0939$
# Trade went from 0.1% to 0.2% (BUY 0.1%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:14:59
# Position change from 52816.0XLMUSDT to 69032.0XLMUSDT.
# BUY 16216.0XLMUSDT at 0.2981$
# Trade went from 0.137% to 0.179% (BUY 0.042%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:15:01
# Position change from -8446.4EOSUSDT to -9825.3EOSUSDT.
# SELL 1378.9EOSUSDT at 4.2321$
# Trade went from -0.312% to -0.363% (SELL 0.051%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:15:03
# Position change from -29.301BTCUSDT to -5.916BTCUSDT.
# BUY 23.385BTCUSDT at 47848.8144$
# Trade went from -12.224% to -2.461% (BUY 9.763%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.02045
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01014
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.0093
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.02002
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -8.00       -4.00        4.00       -13143.00
# 💰CryptoPinoy 2021-10-02 00:15:17
# Position change from -8.0ETHUSDT to -4.0ETHUSDT.
# BUY 4.0ETHUSDT at 3284.8$
# Trade went from -29.302% to -14.656% (BUY 14.646%)
# Status:OPEN
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01302
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01999
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01319
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01301
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01133
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.007
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5638960.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.02619
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       180814.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223570.00
# 2   ETCUSDT     5000.00     5000.00        0.00       261425.00
# 3   ETHUSDT       50.00       50.00        0.00       164645.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       228919.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213000.00
# 6   BTCUSDT       18.00       18.00        0.00       859801.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.00883
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1070.00
# 1    ETHUSDT        4.00        4.00        0.00        13174.00
# 2  ALICEUSDT      100.00      100.00        0.00         1422.00
# 3    BTCUSDT        0.80        0.80        0.00        38220.00
# ####################################################################
# Time for one cycle of traders: 61.2
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.015
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       176461.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       495384.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01172
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7796834.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.03151
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1179313.00
# 1        ADAUSDT   -40406.00   -40406.00        0.00       -90433.00
# 2        BNBUSDT     -128.53     -135.99       -7.46       -56745.00
# 3        ETCUSDT      252.10     -659.37     -911.47       -34623.00
# 4        ETHUSDT     -301.01     -303.46       -2.45      -999510.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91806.00
# 6        TRXUSDT   245127.00   188456.00   -56671.00        17707.00
# 7        RLCUSDT    84955.80    84955.80        0.00       316408.00
# 8        XLMUSDT    69032.00    69032.00        0.00        20611.00
# 9        ADABUSD    48523.00    48523.00        0.00       108677.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       304587.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123257.00
# 13       EOSUSDT    -9825.30   -10135.30     -310.00       -43214.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162576.00
# 15      NEARUSDT    15178.00    15178.00        0.00       116660.00
# 16       SOLBUSD      810.00      810.00        0.00       128520.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107140.00
# 18       ETHBUSD      362.09      362.09        0.00      1193683.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1160308.00
# 20       FILUSDT     1064.50     1064.50        0.00        74793.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124373.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -113070.00
# 23       BTCUSDT       -5.92       -5.92        0.00      -282750.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115664.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111042.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178655.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -652388.00
# 💰ClickHereNow 2021-10-02 00:15:51
# Position change from -128.53BNBUSDT to -135.99BNBUSDT.
# SELL 7.46BNBUSDT at 416.26$
# Trade went from -0.466% to -0.495% (SELL 0.029%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:15:53
# Position change from 252.1ETCUSDT to -659.37ETCUSDT.
# SELL 911.47ETCUSDT at 51.2601$
# Trade went from 0.113% to -0.302% (SELL 0.415%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:15:55
# Position change from -301.011ETHUSDT to -303.459ETHUSDT.
# SELL 2.448ETHUSDT at 3285.17$
# Trade went from -8.622% to -8.715% (SELL 0.093%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:15:58
# Position change from 245127.0TRXUSDT to 188456.0TRXUSDT.
# SELL 56671.0TRXUSDT at 0.0937$
# Trade went from 0.2% to 0.154% (SELL 0.046%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:16:00
# Position change from -9825.3EOSUSDT to -10135.3EOSUSDT.
# SELL 310.0EOSUSDT at 4.24$
# Trade went from -0.363% to -0.377% (SELL 0.014%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01312
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.00676
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.011
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01309
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13173.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01105
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01305
# Couldn't download position for 911korn
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01244
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01685
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01409
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01484
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5605000.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01509
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       180889.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223770.00
# 2   ETCUSDT     5000.00     5000.00        0.00       262586.00
# 3   ETHUSDT       50.00       50.00        0.00       164786.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229277.00
# 5   EOSUSDT    50000.00    50000.00        0.00       212857.00
# 6   BTCUSDT       18.00       18.00        0.00       860322.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01289
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1072.00
# 1    ETHUSDT        4.00        4.00        0.00        13183.00
# 2  ALICEUSDT      100.00      100.00        0.00         1425.00
# 3    BTCUSDT        0.80        0.80        0.00        38239.00
# ####################################################################
# Time for one cycle of traders: 51.69
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01199
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       176603.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       497694.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.00799
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7802731.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.02901
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1179838.00
# 1        ADAUSDT   -40406.00   -40406.00        0.00       -90489.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56784.00
# 3        ETCUSDT     -659.37     -729.43      -70.06       -38430.00
# 4        ETHUSDT     -303.46     -312.17       -8.71     -1029581.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91948.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17721.00
# 7        RLCUSDT    84955.80    84955.80        0.00       316569.00
# 8        XLMUSDT    69032.00    17071.00   -51961.00         5113.00
# 9        ADABUSD    48523.00    48523.00        0.00       108732.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       305054.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123328.00
# 13       EOSUSDT   -10135.30   -10135.30        0.00       -43197.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162776.00
# 15      NEARUSDT    15178.00    15178.00        0.00       117195.00
# 16       SOLBUSD      810.00      810.00        0.00       128486.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107199.00
# 18       ETHBUSD      362.09      362.09        0.00      1194686.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1162169.00
# 20       FILUSDT     1064.50     1064.50        0.00        75123.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124524.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -113044.00
# 23       BTCUSDT       -5.92       -6.88       -0.97      -329125.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115706.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111191.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178683.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -653458.00
# 💰ClickHereNow 2021-10-02 00:16:42
# Position change from -659.37ETCUSDT to -729.43ETCUSDT.
# SELL 70.06ETCUSDT at 52.509$
# Trade went from -0.302% to -0.335% (SELL 0.033%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:16:45
# Position change from -303.459ETHUSDT to -312.172ETHUSDT.
# SELL 8.713ETHUSDT at 3293.7246$
# Trade went from -8.715% to -8.977% (SELL 0.262%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:16:47
# Position change from 69032.0XLMUSDT to 17071.0XLMUSDT.
# SELL 51961.0XLMUSDT at 0.2986$
# Trade went from 0.18% to 0.045% (SELL 0.135%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:16:49
# Position change from -5.916BTCUSDT to -6.883BTCUSDT.
# SELL 0.967BTCUSDT at 47794.1$
# Trade went from -2.465% to -2.87% (SELL 0.405%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01338
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01225
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01253
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01336
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13202.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01855
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01565
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.00713
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01382
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01211
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01202
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5692247.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01149
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       181257.00
# 1   ADAUSDT   100000.00   100000.00        0.00       224036.00
# 2   ETCUSDT     5000.00     5000.00        0.00       264520.00
# 3   ETHUSDT       50.00       50.00        0.00       165000.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229490.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213768.00
# 6   BTCUSDT       18.00       18.00        0.00       860705.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01434
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1074.00
# 1    ETHUSDT        4.00        4.00        0.00        13204.00
# 2  ALICEUSDT      100.00      100.00        0.00         1437.00
# 3    BTCUSDT        0.80        0.80        0.00        38256.00
# ####################################################################
# Time for one cycle of traders: 50.87
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.00636
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       175347.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       497110.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01124
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7802548.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01611
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1179723.00
# 1        ADAUSDT   -40406.00   -40406.00        0.00       -90542.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56809.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -38674.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1030342.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91953.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17736.00
# 7        RLCUSDT    84955.80    84955.80        0.00       317015.00
# 8        XLMUSDT    17071.00    17071.00        0.00         5118.00
# 9        ADABUSD    48523.00    48523.00        0.00       108782.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       304978.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123369.00
# 13       EOSUSDT   -10135.30   -10135.30        0.00       -43327.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       163063.00
# 15      NEARUSDT    15178.00    15178.00        0.00       117125.00
# 16       SOLBUSD      810.00      810.00        0.00       128513.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107200.00
# 18       ETHBUSD      362.09      362.09        0.00      1195514.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1161190.00
# 20       FILUSDT     1064.50     1064.50        0.00        75243.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124660.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -113091.00
# 23       BTCUSDT       -6.88       -7.81       -0.93      -373608.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115896.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111264.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -179010.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -664320.00
# 💰ClickHereNow 2021-10-02 00:17:33
# Position change from -6.883BTCUSDT to -7.814BTCUSDT.
# SELL 0.931BTCUSDT at 47817.13$
# Trade went from -2.87% to -3.257% (SELL 0.387%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01621
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01076
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.00681
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01574
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13214.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.02034
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.02442
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.00599
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01304
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.00805
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01408
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5705500.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01396
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       181213.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223949.00
# 2   ETCUSDT     5000.00     5000.00        0.00       264692.00
# 3   ETHUSDT       50.00       50.00        0.00       164952.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229335.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213753.00
# 6   BTCUSDT       18.00       18.00        0.00       860508.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01919
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1074.00
# 1    ETHUSDT        4.00        4.00        0.00        13197.00
# 2  ALICEUSDT      100.00      100.00        0.00         1439.00
# 3    BTCUSDT        0.80        0.80        0.00        38245.00
# ####################################################################
# Time for one cycle of traders: 43.76
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01804
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       175014.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       497403.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01301
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7798579.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.02695
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1179448.00
# 1        ADAUSDT   -40406.00   -40406.00        0.00       -90375.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56717.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -38541.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1029262.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91869.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17720.00
# 7        RLCUSDT    84955.80    84955.80        0.00       316991.00
# 8        XLMUSDT    17071.00    17071.00        0.00         5116.00
# 9        ADABUSD    48523.00    48523.00        0.00       108627.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       304594.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123191.00
# 13       EOSUSDT   -10135.30   -10135.30        0.00       -43304.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162819.00
# 15      NEARUSDT    15178.00    15178.00        0.00       117009.00
# 16       SOLBUSD      810.00      810.00        0.00       128399.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107214.00
# 18       ETHBUSD      362.09      362.09        0.00      1194285.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1159148.00
# 20       FILUSDT     1064.50     1064.50        0.00        74995.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124597.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -112961.00
# 23       BTCUSDT       -7.81       -7.81        0.00      -373390.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115875.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111181.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178875.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -662573.00
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.00496
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01398
# Couldn't download position for BananaMan1
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01804
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01507
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13194.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.0212
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.00415
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01318
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.00851
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01646
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01412
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5759279.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01489
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       181194.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223700.00
# 2   ETCUSDT     5000.00     5000.00        0.00       263889.00
# 3   ETHUSDT       50.00       50.00        0.00       164759.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229116.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213438.00
# 6   BTCUSDT       18.00       18.00        0.00       860249.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01794
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1074.00
# 1    ETHUSDT        4.00        4.00        0.00        13181.00
# 2  ALICEUSDT      100.00      100.00        0.00         1443.00
# 3    BTCUSDT        0.80        0.80        0.00        38235.00
# ####################################################################
# Time for one cycle of traders: 38.86
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.00522
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       173833.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       496231.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.00721
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7799375.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.02475
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1179464.00
# 1        ADAUSDT   -40406.00   -40406.00        0.00       -90369.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56689.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -38502.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1028636.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91786.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17721.00
# 7        RLCUSDT    84955.80    84955.80        0.00       316664.00
# 8        XLMUSDT    17071.00    17071.00        0.00         5109.00
# 9        ADABUSD    48523.00    48523.00        0.00       108635.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       304580.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123123.00
# 13       EOSUSDT   -10135.30   -10135.30        0.00       -43268.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162692.00
# 15      NEARUSDT    15178.00    15178.00        0.00       116966.00
# 16       SOLBUSD      810.00      810.00        0.00       128364.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107194.00
# 18       ETHBUSD      362.09      362.09        0.00      1193721.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1159980.00
# 20       FILUSDT     1064.50     1064.50        0.00        75017.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124577.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -112892.00
# 23       BTCUSDT       -7.81       -7.81        0.00      -373507.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115824.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111064.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178783.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -672142.00
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01344
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01805
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.00784
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.00874
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13181.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.0171
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01291
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01052
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01971
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01594
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.00342
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5756067.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01227
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       180942.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223611.00
# 2   ETCUSDT     5000.00     5000.00        0.00       264396.00
# 3   ETHUSDT       50.00       50.00        0.00       164650.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       228898.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213219.00
# 6   BTCUSDT       18.00       18.00        0.00       860066.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01773
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1072.00
# 1    ETHUSDT        4.00        4.00        0.00        13172.00
# 2  ALICEUSDT      100.00      100.00        0.00         1451.00
# 3    BTCUSDT        0.80        0.80        0.00        38226.00
# ####################################################################
# Time for one cycle of traders: 42.69
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01538
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       173924.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       494698.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01601
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7797323.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.03306
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1178788.00
# 1        ADAUSDT   -40406.00   -39024.00     1382.00       -87196.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56610.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -38499.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1027412.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91736.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17711.00
# 7        RLCUSDT    84955.80    84955.80        0.00       316628.00
# 8        XLMUSDT    17071.00    17071.00        0.00         5104.00
# 9        ADABUSD    48523.00    48523.00        0.00       108500.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       304075.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       122941.00
# 13       EOSUSDT   -10135.30   -10135.30        0.00       -43189.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162408.00
# 15      NEARUSDT    15178.00    15178.00        0.00       116764.00
# 16       SOLBUSD      810.00      810.00        0.00       128254.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107186.00
# 18       ETHBUSD      362.09      362.09        0.00      1192595.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1159944.00
# 20       FILUSDT     1064.50     1064.50        0.00        74778.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -124441.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -112813.00
# 23       BTCUSDT       -7.81       -7.81        0.00      -373267.00
# 24       XRPBUSD   112034.20   112034.20        0.00       115748.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111069.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -178626.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -666685.00
# 💰ClickHereNow 2021-10-02 00:19:39
# Position change from -40406.0ADAUSDT to -39024.0ADAUSDT.
# BUY 1382.0ADAUSDT at 2.2365$
# Trade went from -0.788% to -0.76% (BUY 0.028%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01505
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01499
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01502
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01192
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13161.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01962
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01906
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.011
# Couldn't download position for BakeAlsoShare
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01405
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.013
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01408
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5788968.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.00988
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       180861.00
# 1   ADAUSDT   100000.00   100000.00        0.00       223344.00
# 2   ETCUSDT     5000.00     5000.00        0.00       263473.00
# 3   ETHUSDT       50.00       50.00        0.00       164638.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       228924.00
# 5   EOSUSDT    50000.00    50000.00        0.00       212922.00
# 6   BTCUSDT       18.00       18.00        0.00       860022.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.012
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1072.00
# 1    ETHUSDT        4.00        4.00        0.00        13173.00
# 2  ALICEUSDT      100.00      100.00        0.00         1449.00
# 3    BTCUSDT        0.80        0.80        0.00        38225.00
# ...
# 💰ClickHereNow 2021-10-02 00:25:15
# Position change from 41547.0XLMUSDT to 22126.0XLMUSDT.
# SELL 19421.0XLMUSDT at 0.2995$
# Trade went from 0.108% to 0.058% (SELL 0.05%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:25:17
# Position change from -10135.3EOSUSDT to -10203.7EOSUSDT.
# SELL 68.4EOSUSDT at 4.2825$
# Trade went from -0.378% to -0.382% (SELL 0.004%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 00:25:19
# Position change from -9.665BTCUSDT to -12.018BTCUSDT.
# SELL 2.353BTCUSDT at 47867.49$
# Trade went from -4.034% to -5.022% (SELL 0.988%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01142
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.00834
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.00744
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.02153
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13216.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.018
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.0245
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01629
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.02023
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.02699
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.005
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5829334.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01768
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       182436.00
# 1   ADAUSDT   100000.00   100000.00        0.00       224446.00
# 2   ETCUSDT     5000.00     5000.00        0.00       271079.00
# 3   ETHUSDT       50.00       50.00        0.00       165204.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229693.00
# 5   EOSUSDT    50000.00    50000.00        0.00       215050.00
# 6   BTCUSDT       18.00       18.00        0.00       862885.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01412
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1078.00
# 1    ETHUSDT        4.00        4.00        0.00        13215.00
# 2  ALICEUSDT      100.00      100.00        0.00         1439.00
# 3    BTCUSDT        0.80        0.80        0.00        38344.00
# ####################################################################
# Time for one cycle of traders: 48.88
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01505
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       172283.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       496163.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01239
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7819790.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01815
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1182313.00
# 1        ADAUSDT   -39024.00   -39024.00        0.00       -87528.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56923.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -39550.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1030948.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -92015.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17792.00
# 7        RLCUSDT    84955.80    84955.80        0.00       318466.00
# 8        XLMUSDT    22126.00    22126.00        0.00         6650.00
# 9        ADABUSD    48523.00    48523.00        0.00       108886.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       306035.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123654.00
# 13       EOSUSDT   -10203.70   -10203.70        0.00       -43905.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162638.00
# 15      NEARUSDT    15178.00    15178.00        0.00       117537.00
# 16       SOLBUSD      810.00      810.00        0.00       129042.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107441.00
# 18       ETHBUSD      362.09      362.09        0.00      1196536.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1170159.00
# 20       FILUSDT     1064.50     1064.50        0.00        75374.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -125405.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -113534.00
# 23       BTCUSDT      -12.02      -12.02        0.00      -575982.00
# 24       XRPBUSD   112034.20   112034.20        0.00       116323.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111382.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -179625.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -673222.00
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01533
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01237
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01169
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01875
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00       -4.00        0.00       -13205.00
# 1  BTCUSDT        0.00       -0.50       -0.50       -23955.00
# 2  AXSUSDT        0.00      -10.00      -10.00        -1160.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01217
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01403
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01987
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01783
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01383
# No positions for GeboyMujaer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.0146
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5837219.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01161
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       182276.00
# 1   ADAUSDT   100000.00   100000.00        0.00       224194.00
# 2   ETCUSDT     5000.00     5000.00        0.00       270865.00
# 3   ETHUSDT       50.00       50.00        0.00       165078.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       229585.00
# 5   EOSUSDT    50000.00    50000.00        0.00       215109.00
# 6   BTCUSDT       18.00       18.00        0.00       862302.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01169
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1077.00
# 1    ETHUSDT        4.00        4.00        0.00        13207.00
# 2  ALICEUSDT      100.00      100.00        0.00         1438.00
# 3    BTCUSDT        0.80        0.80        0.00        38325.00
# ####################################################################
# Time for one cycle of traders: 41.06
# ####################################################################
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01199
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       171690.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       496344.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.02105
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7816319.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.02221
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1181775.00
# 1        ADAUSDT   -39024.00   -39024.00        0.00       -87496.00
# 2        BNBUSDT     -135.99     -135.99        0.00       -56933.00
# 3        ETCUSDT     -729.43     -729.43        0.00       -39705.00
# 4        ETHUSDT     -312.17     -312.17        0.00     -1029951.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -91990.00
# 6        TRXUSDT   188456.00   188456.00        0.00        17784.00
# 7        RLCUSDT    84955.80    84955.80        0.00       318366.00
# 8        XLMUSDT    22126.00    22126.00        0.00         6643.00
# 9        ADABUSD    48523.00    48523.00        0.00       108844.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       305856.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123655.00
# 13       EOSUSDT   -10203.70   -10203.70        0.00       -43890.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       162377.00
# 15      NEARUSDT    15178.00    15178.00        0.00       117355.00
# 16       SOLBUSD      810.00      810.00        0.00       129276.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       107530.00
# 18       ETHBUSD      362.09      362.09        0.00      1195475.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1168782.00
# 20       FILUSDT     1064.50     1064.50        0.00        75242.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -125326.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -113741.00
# 23       BTCUSDT      -12.02      -12.02        0.00      -575553.00
# 24       XRPBUSD   112034.20   112034.20        0.00       116331.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       111342.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -179635.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -676016.00
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.00762
# No positions for CheerWindCard, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01952
# No positions for BananaMan1, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01009
# No positions for BigPiePlayer, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.0117
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -4.00      -10.00       -6.00       -32983.00
# 1  BTCUSDT       -0.50       -0.50        0.00       -23943.00
# 2  AXSUSDT      -10.00      -10.00        0.00        -1163.00
# 💰CryptoPinoy 2021-10-02 00:26:55
# Position change from -4.0ETHUSDT to -10.0ETHUSDT.
# SELL 6.0ETHUSDT at 3301.1636$
# Trade went from -14.725% to -36.779% (SELL 22.054%)
# Status:OPEN
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.01085
# No positions for ChurchChalkUnder, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.00764
# No positions for 911korn, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01097
# No positions for BakeAlsoShare, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.02407
# No positions for SABSAB, but still save.
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00

# %%
do_query(query="select MAX(id) as id from positions")["id"][0]

# %%
do_query(query=f"select distinct(request_id) from POSITIONS where encryptedUid = '{trader}' order by request_id desc limit 2")

# %%
do_query(query="select*from positions where nick='ClickHereNow'")
