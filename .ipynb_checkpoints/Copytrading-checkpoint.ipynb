# %%
import sqlite3 
import pandas as pd 
import requests
import json  
from datetime import datetime
import secrets
import telegram #pip install python-telegram-bot --upgrade
import time
import math

pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', 500) 
pd.set_option('display.max_rows', 500) 

def connect_create_table(name_db='db.db'):
    conn = sqlite3.connect(name_db)  # You can create a new database by changing the name within the quotes
    c = conn.cursor() # The database will be saved in the location where your 'py' file is saved

    # Create table - CLIENTS
    c.execute('''CREATE TABLE if not exists POSITIONS
                 ([id] INTEGER PRIMARY KEY,
                 [date] DATETIME,
                 [encryptedUid] TEXT,
                 [nick] TEXT,
                 [symbol] TEXT,
                 [status] TEXT,
                 [entryPrice] FLOAT,
                 [markPrice] FLOAT,
                 [pnl] FLOAT,
                 [roe] FLOAT,
                 [amount] FLOAT,
                 [amount_usd] FLOAT,
                 [updateTimeStamp] TEXT,
                 [request_id] INT
                 )''')
    conn.commit()

connect_create_table()

# %%
def human_format(num):
    num = float(num)
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.2f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

# %%
def insert_in_table(trader_info, request_id, vector, status):
    encryptedUid = trader_info[0]
    nick         = trader_info[1]
    
    try:
        sqliteConnection = sqlite3.connect('db.db')
        cursor = sqliteConnection.cursor()
        
        symbol      = vector[0]
        entryPrice  = vector[1]
        markPrice   = vector[2]
        pnl         = vector[3]
        row         = vector[4]
        try: amount = float(vector[5])
        except: amount = 0
        amount_usd  = round(markPrice * amount,0)
        print(amount_usd)
        updateTimestamp = time.time()
        date        = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        # Need to add more info of student (such as the txns)
        sqlite_insert_with_param = """INSERT INTO POSITIONS 
                          (date, encryptedUid, nick, symbol, status, entryPrice, markPrice, pnl, roe, amount, amount_usd, updateTimeStamp, request_id) 
                          VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?,?,?);"""

        data_tuple = (date, encryptedUid, nick, symbol, status, entryPrice, markPrice, pnl, row, amount, amount_usd, updateTimestamp,request_id) 
        cursor.execute(sqlite_insert_with_param, data_tuple)
        sqliteConnection.commit()

        cursor.close()

    except sqlite3.Error as error:
        print("Failed to insert Python variable into sqlite table", error)
    finally:
        if sqliteConnection:
            sqliteConnection.close()

# %%
def do_query(db="db.db", query="SELECT * FROM POSITIONS"):    
    con = sqlite3.connect(db)
    df = pd.read_sql_query(query, con)
    
    return df

# %%
def get_positions(trader):
    endpoint = "https://www.binance.com/bapi/futures/v1/public/future/leaderboard/getOtherPosition"
    params   =  {"encryptedUid":trader,  "tradeType":"PERPETUAL"}
    headers  =  {"content-type":"application/json;charset=UTF-8"}
    response = requests.post(endpoint, json=params, headers=headers) #Add proxies = proxyDict # Attention to JSON = PARAMS
    result   = response.json()
    
    return result

# %%
def send_message(text, chat_id = "-1001455341077"):
    my_bot  = telegram.Bot("814569733:AAGmMk_P4p8EdLkj-fj2fVziyByxHIcJpm0")
    my_bot.send_message(chat_id=chat_id, text=text, parse_mode = "Markdown")

# %%
def send_message_discord(text):
    #Webhook of my channel. Click on edit channel --> Webhooks --> Creates webhook
    webhook = "https://discord.com/api/webhooks/892399337731133500/_IE9zchjLp3lRrImBt8sp_YgrI8A9Kan1Vc6wv7eY7vvkVNEAGF-YkVkiUF4pKxT5J3R"
    data    = {"content": text}
    response = requests.post(webhook, json=data)

# %%
def create_message(trader, row, trader_max_size):

    if row["difference"] > 0:
        trade_type = "BUY"
    else:
        trade_type = "SELL" 
    
    status           = row["status_new"]
    current_position = round(row["amount_new"],4)
    old_position     = round(row["amount_old"],4)
    price            = str(round(row["markPrice_old"],4))
    difference       = str(abs(row["difference"]))
    symbol           = row["symbol"]
    date             = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    amount_usd       = row["amount_usd_new"])
    current_position_percent = str(round(100* current_position / trader_max_size,3))
    old_position_percent     = str(round(100* old_position / trader_max_size,3))
    delta_percent    = str(round(abs(float(current_position_percent) - float(old_position_percent)),3))
    
    message =  "💰" + trader + " " + date + "\nPosition change from " + str(old_position) + symbol + " to " + str(current_position) + symbol + ".\n" + trade_type + " " + difference + symbol + " at " + price + "$" + "\nTrade went from" + old_position_percent + "% to "+ current_position_percent +"% (" + trade_type + " " + delta_percent + "%)\nStatus:" + status 
    return message

# %%
def message_logic(row, trader_dict, trader_max_size):
    if row["status_old"] == "OPEN":
        if row["difference"] != 0:   
            if   trader_dict == "TraderT":      chat_id = -542063577
            elif trader_dict == "ClickHereNow": chat_id = -591308509
            else:   chat_id = -530891051    
            message = create_message(trader_dict, row, trader_max_size)

            try: 
                send_message(message, chat_id)
                print(message)
            except: print("Too many messages")
            if trader_dict in ["TraderT","ADnefina"] : send_message_discord(message)
            time.sleep(2)

# %%
def get_positions_db(two_ids):
    # Get last update from trader.             
    this_id, last_id = two_ids["request_id"][0], two_ids["request_id"][1]

    # Get all the positions with that request_id
    new_positions   = do_query(query=f"SELECT * FROM POSITIONS WHERE request_id = '{this_id}'")
    old_positions   = do_query(query=f"SELECT * FROM POSITIONS WHERE request_id = '{last_id}'")

    # Compare the previous position with the new one, pair by pair
    both               = old_positions.merge(new_positions, "outer", on ="symbol", suffixes=('_old', '_new')).fillna(0) #Filling nas (if previous or new position is na, is because is not present, hence 0)
    both["difference"] = round(both["amount_new"] - both["amount_old"],4)
    print(both[["symbol","amount_old","amount_new","difference", "amount_usd_new"]])
    
    return both

# %%
def get_trader_max_size(trader,tol = 0.20):
    start = time.time()
    trades        = do_query(query=f"select amount_usd, request_id from positions where encryptedUid = '{trader}'")
    trades["amount_usd"]    = abs(trades["amount_usd"])
    sum_positions = trades.groupby(['request_id'])["amount_usd"].sum()
    position_max  = sum_positions.max()
    trader_max_size = position_max*(1+tol)
    print("time for getting trader max size:", round( time.time() - start,5))
    return trader_max_size

# %%
names    = {"CCF3E0CB0AAD54D9D6B4CEC5E3E741D2":"TraderT", 
            "49A7275656A7ABF56830126ACC619FEB":"ADnefina", 
            "A532C4316C00206168F795EDFBB3E164":"ClickHereNow", 
            "D3AFE978B3F0CD58489BC27B35906769":"CheerWindCard",
            "FB23E1A8B7E2944FAAEC6219BBDF8243":"BananaMan1", 
            "F318AE1B1BB3AEF4EDBD36E5AE250CD1":"BigPiePlayer", 
            "2F9D01E80429F97670415A5A5DDD9405":"CryptoPinoy",
            "95ACEF9493428B28CCADDA38A2127859":"ChurchChalkUnder",
            "382066A3597798ED9F69FECBCABAA00D":"911korn",
            "15A34DAA83C4B2D7F3A4BBAB4D2FECCA":"BakeAlsoShare",
            "3E478F9133714216B608E95B4ACF1FA3":"SABSAB",
            "B936AEC059917C5A730D45922A9F4334":"GeboyMujaer",
            "8D27A8FA0C0A726CF01A7D11E0095577":"Nothingness",
            "C6EC5B8B2D08F5748A1D8D3D849023A3":"GetSwifty",
            "191792DA7B3EEB10DAF1D51B6926F2E1":"Mikkiko",}

#names = {"A532C4316C00206168F795EDFBB3E164":"ClickHereNow"}

traders  = list(names.keys())
keys     = ["symbol", "entryPrice", "markPrice", "pnl", "roe", "amount"]

while True:
    for trader in traders:
        print(" ")
        print("______________________", names[trader], "______________________")
        trader_info = [trader, names[trader]]    # Write the name of the trader
        trader_max_size = get_trader_max_size(trader)
        
        # Download data
        try:
            position_array   = get_positions(trader)     # Get the current position of the trader
            positions        = position_array["data"]["otherPositionRetList"]
            count = do_query(query="SELECT COUNT(*) as count FROM positions")["count"][0]
            if count > 0: request_id  = int(do_query(query="select MAX(id) as id from positions")["id"][0])
            else:         request_id = 0

        except:
            print(f"Couldn't download position for {names[trader]}")
            continue #This is useful not to mix stuff between positions and no positions        
        
        # Insert in the database what we downloaded
        if not positions:
            print(f"No positions for {names[trader]}, but still save.")
            empty    = [0,0,0,0,0,0] # Need to get the timestamp right!
            insert_in_table(trader_info, request_id, empty, "CLOSE")

        if positions:
            for i in range(len(positions)):
                row = pd.DataFrame(positions).loc[i]
                vector = [row["symbol"], row["entryPrice"], row["markPrice"], row["pnl"], row["roe"], row["amount"]]
                status = "CLOSED" if row["amount"] == 0 else "OPEN"
                insert_in_table(trader_info, request_id, vector, status)
        
        # Get last updates
        two_ids = do_query(query=f"select distinct(request_id) from POSITIONS where encryptedUid = '{trader}' order by request_id desc limit 2")
        
        if len(two_ids)>=2: # if the trader is in the database, check the delta
            both = get_positions_db(two_ids)

            for i in range(len(both)):
                row = both.loc[i]
                message_logic(row, names[trader], trader_max_size)

            time.sleep(2)
# Out:
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.00904
# 167670.0
# 504089.0
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       167670.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       504089.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.0128
# 7854705.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7854705.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01599
# 1187866.0
# -90287.0
# -97649.0
# -37168.0
# -1064375.0
# -92814.0
# -18814.0
# 319865.0
# 19270.0
# 109667.0
# 305565.0
# -1.0
# 124397.0
# -22169.0
# 164118.0
# 118863.0
# 130964.0
# 108591.0
# 1198799.0
# -1163601.0
# 76083.0
# -125314.0
# -115261.0
# -1267575.0
# 116750.0
# 112268.0
# -180243.0
# -643091.0
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1187866.00
# 1        ADAUSDT   -39969.00   -39969.00        0.00       -90287.00
# 2        BNBUSDT     -231.74     -231.74        0.00       -97649.00
# 3        ETCUSDT     -716.43     -716.43        0.00       -37168.00
# 4        ETHUSDT     -320.10     -321.66       -1.56     -1064375.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -92814.00
# 6        TRXUSDT  -198441.00  -198441.00        0.00       -18814.00
# 7        RLCUSDT    84955.80    84955.80        0.00       319865.00
# 8        XLMUSDT    76443.00    64111.00   -12332.00        19270.00
# 9        ADABUSD    48523.00    48523.00        0.00       109667.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       305565.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       124397.00
# 13       EOSUSDT    -4475.90    -5186.20     -710.30       -22169.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       164118.00
# 15      NEARUSDT    15178.00    15178.00        0.00       118863.00
# 16       SOLBUSD      810.00      810.00        0.00       130964.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       108591.00
# 18       ETHBUSD      362.09      362.09        0.00      1198799.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1163601.00
# 20       FILUSDT     1064.50     1064.50        0.00        76083.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -125314.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -115261.00
# 23       BTCUSDT      -26.33      -26.33        0.00     -1267575.00
# 24       XRPBUSD   112034.20   112034.20        0.00       116750.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       112268.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -180243.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -643091.00
# 💰ClickHereNow 2021-10-02 01:59:26
# Position change from -320.101ETHUSDT to -321.661ETHUSDT.
# SELL 1.56ETHUSDT at 3307.8$
# Trade went from-0.003% to -0.003% (SELL 0.0%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 01:59:29
# Position change from 76443.0XLMUSDT to 64111.0XLMUSDT.
# SELL 12332.0XLMUSDT at 0.3004$
# Trade went from0.707% to 0.593% (SELL 0.114%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 01:59:31
# Position change from -4475.9EOSUSDT to -5186.2EOSUSDT.
# SELL 710.3EOSUSDT at 4.273$
# Trade went from-0.041% to -0.048% (SELL 0.007%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.01139
# No positions for CheerWindCard, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.00702
# No positions for BananaMan1, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.0114
# No positions for BigPiePlayer, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.00926
# -26462.0
# -48123.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  ETHUSDT       -8.00       -8.00        0.00       -26462.00
# 1  BTCUSDT       -1.00       -1.00        0.00       -48123.00
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.00535
# No positions for ChurchChalkUnder, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01212
# Couldn't download position for 911korn
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01785
# Couldn't download position for BakeAlsoShare
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.01099
# No positions for SABSAB, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01251
# No positions for GeboyMujaer, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.00868
# 5522606.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5522606.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.01165
# 182358.0
# 225527.0
# 259410.0
# 165429.0
# 231198.0
# 213723.0
# 866230.0
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       182358.00
# 1   ADAUSDT   100000.00   100000.00        0.00       225527.00
# 2   ETCUSDT     5000.00     5000.00        0.00       259410.00
# 3   ETHUSDT       50.00       50.00        0.00       165429.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       231198.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213723.00
# 6   BTCUSDT       18.00       18.00        0.00       866230.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01171
# 1083.0
# 13241.0
# 1450.0
# 38504.0
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1083.00
# 1    ETHUSDT        4.00        4.00        0.00        13241.00
# 2  ALICEUSDT      100.00      100.00        0.00         1450.00
# 3    BTCUSDT        0.80        0.80        0.00        38504.00
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01308
# 167158.0
# 503179.0
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       167158.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       503179.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.0174
# 7855201.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7855201.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01504
# 1187651.0
# -94355.0
# -75735.0
# -37171.0
# -1090335.0
# -92785.0
# -18818.0
# 319693.0
# 19274.0
# 109483.0
# 305791.0
# -1.0
# 124297.0
# -25229.0
# 163979.0
# 118885.0
# 130889.0
# 108562.0
# 1198984.0
# -1163531.0
# 76105.0
# -125298.0
# -115237.0
# -1311749.0
# 116818.0
# 112253.0
# -180368.0
# -640894.0
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1187651.00
# 1        ADAUSDT   -39969.00   -41827.00    -1858.00       -94355.00
# 2        BNBUSDT     -231.74     -179.97       51.77       -75735.00
# 3        ETCUSDT     -716.43     -716.43        0.00       -37171.00
# 4        ETHUSDT     -321.66     -329.32       -7.66     -1090335.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -92785.00
# 6        TRXUSDT  -198441.00  -198441.00        0.00       -18818.00
# 7        RLCUSDT    84955.80    84955.80        0.00       319693.00
# 8        XLMUSDT    64111.00    64111.00        0.00        19274.00
# 9        ADABUSD    48523.00    48523.00        0.00       109483.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       305791.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       124297.00
# 13       EOSUSDT    -5186.20    -5903.20     -717.00       -25229.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       163979.00
# 15      NEARUSDT    15178.00    15178.00        0.00       118885.00
# 16       SOLBUSD      810.00      810.00        0.00       130889.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       108562.00
# 18       ETHBUSD      362.09      362.09        0.00      1198984.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1163531.00
# 20       FILUSDT     1064.50     1064.50        0.00        76105.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -125298.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -115237.00
# 23       BTCUSDT      -26.33      -27.25       -0.92     -1311749.00
# 24       XRPBUSD   112034.20   112034.20        0.00       116818.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       112253.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -180368.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -640894.00
# 💰ClickHereNow 2021-10-02 02:00:12
# Position change from -39969.0ADAUSDT to -41827.0ADAUSDT.
# SELL 1858.0ADAUSDT at 2.2589$
# Trade went from-0.37% to -0.387% (SELL 0.017%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:00:15
# Position change from -231.74BNBUSDT to -179.97BNBUSDT.
# BUY 51.77BNBUSDT at 421.3723$
# Trade went from-0.002% to -0.002% (BUY 0.0%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:00:17
# Position change from -321.661ETHUSDT to -329.316ETHUSDT.
# SELL 7.655ETHUSDT at 3308.9967$
# Trade went from-0.003% to -0.003% (SELL 0.0%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:00:19
# Position change from -5186.2EOSUSDT to -5903.2EOSUSDT.
# SELL 717.0EOSUSDT at 4.2746$
# Trade went from-0.048% to -0.055% (SELL 0.007%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:00:22
# Position change from -26.332BTCUSDT to -27.255BTCUSDT.
# SELL 0.923BTCUSDT at 48138.1881$
# Trade went from-0.0% to -0.0% (SELL 0.0%)
# Status:OPEN
#
# ______________________ CheerWindCard ______________________
# time for getting trader max size: 0.0138
# No positions for CheerWindCard, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BananaMan1 ______________________
# time for getting trader max size: 0.01486
# Couldn't download position for BananaMan1
#
# ______________________ BigPiePlayer ______________________
# time for getting trader max size: 0.01606
# Couldn't download position for BigPiePlayer
#
# ______________________ CryptoPinoy ______________________
# time for getting trader max size: 0.01597
# Couldn't download position for CryptoPinoy
#
# ______________________ ChurchChalkUnder ______________________
# time for getting trader max size: 0.013
# Couldn't download position for ChurchChalkUnder
#
# ______________________ 911korn ______________________
# time for getting trader max size: 0.01206
# No positions for 911korn, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ BakeAlsoShare ______________________
# time for getting trader max size: 0.01502
# No positions for BakeAlsoShare, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ SABSAB ______________________
# time for getting trader max size: 0.013
# No positions for SABSAB, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ GeboyMujaer ______________________
# time for getting trader max size: 0.01169
# No positions for GeboyMujaer, but still save.
# 0.0
#   symbol  amount_old  amount_new  difference  amount_usd_new
# 0      0        0.00        0.00        0.00            0.00
#
# ______________________ Nothingness ______________________
# time for getting trader max size: 0.01203
# 5587439.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  AXSUSDT    50000.00    50000.00        0.00      5587439.00
#
# ______________________ GetSwifty ______________________
# time for getting trader max size: 0.012
# 182350.0
# 225235.0
# 259089.0
# 165554.0
# 231185.0
# 213728.0
# 866052.0
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0  IOTAUSDT   138750.10   138750.10        0.00       182350.00
# 1   ADAUSDT   100000.00   100000.00        0.00       225235.00
# 2   ETCUSDT     5000.00     5000.00        0.00       259089.00
# 3   ETHUSDT       50.00       50.00        0.00       165554.00
# 4  DOGEUSDT  1037945.00  1037945.00        0.00       231185.00
# 5   EOSUSDT    50000.00    50000.00        0.00       213728.00
# 6   BTCUSDT       18.00       18.00        0.00       866052.00
#
# ______________________ Mikkiko ______________________
# time for getting trader max size: 0.01258
# 1082.0
# 13245.0
# 1448.0
# 38493.0
#       symbol  amount_old  amount_new  difference  amount_usd_new
# 0  SUSHIUSDT      100.00      100.00        0.00         1082.00
# 1    ETHUSDT        4.00        4.00        0.00        13245.00
# 2  ALICEUSDT      100.00      100.00        0.00         1448.00
# 3    BTCUSDT        0.80        0.80        0.00        38493.00
#
# ______________________ TraderT ______________________
# time for getting trader max size: 0.01203
# 166179.0
# 505204.0
#      symbol  amount_old  amount_new  difference  amount_usd_new
# 0   OMGUSDT    13094.00    13094.00        0.00       166179.00
# 1  DYDXUSDT    22545.70    22545.70        0.00       505204.00
#
# ______________________ ADnefina ______________________
# time for getting trader max size: 0.01054
# 7852067.0
#     symbol  amount_old  amount_new  difference  amount_usd_new
# 0  BTCUSDT      163.19      163.19        0.00      7852067.00
#
# ______________________ ClickHereNow ______________________
# time for getting trader max size: 0.01465
# 1186999.0
# -94202.0
# -54792.0
# -37123.0
# -1093614.0
# -92594.0
# -13149.0
# 319302.0
# 19228.0
# 109305.0
# 306475.0
# -1.0
# 123943.0
# -24937.0
# 163709.0
# 118409.0
# 130672.0
# 108517.0
# 1198784.0
# -1162778.0
# 76046.0
# -125267.0
# -115021.0
# -1311251.0
# 116740.0
# 112080.0
# -180248.0
# -648418.0
#           symbol  amount_old  amount_new  difference  amount_usd_new
# 0        BTCBUSD       24.66       24.66        0.00      1186999.00
# 1        ADAUSDT   -41827.00   -41827.00        0.00       -94202.00
# 2        BNBUSDT     -179.97     -130.50       49.47       -54792.00
# 3        ETCUSDT     -716.43     -716.43        0.00       -37123.00
# 4        ETHUSDT     -329.32     -330.31       -0.99     -1093614.00
# 5       DOGEUSDT  -416000.00  -416000.00        0.00       -92594.00
# 6        TRXUSDT  -198441.00  -138717.00    59724.00       -13149.00
# 7        RLCUSDT    84955.80    84955.80        0.00       319302.00
# 8        XLMUSDT    64111.00    64111.00        0.00        19228.00
# 9        ADABUSD    48523.00    48523.00        0.00       109305.00
# 10      TOMOUSDT   128408.00   128408.00        0.00       306475.00
# 11      DODOUSDT       -1.00       -1.00        0.00           -1.00
# 12       BNBBUSD      295.34      295.34        0.00       123943.00
# 13       EOSUSDT    -5903.20    -5832.50       70.70       -24937.00
# 14      ATOMUSDT     4332.25     4332.25        0.00       163709.00
# 15      NEARUSDT    15178.00    15178.00        0.00       118409.00
# 16       SOLBUSD      810.00      810.00        0.00       130672.00
# 17  1000SHIBUSDT 14101137.00 14101137.00        0.00       108517.00
# 18       ETHBUSD      362.09      362.09        0.00      1198784.00
# 19       UNIUSDT   -45399.00   -45399.00        0.00     -1162778.00
# 20       FILUSDT     1064.50     1064.50        0.00        76046.00
# 21      DEFIUSDT      -52.27      -52.27        0.00      -125267.00
# 22       SOLUSDT     -713.00     -713.00        0.00      -115021.00
# 23       BTCUSDT      -27.25      -27.25        0.00     -1311251.00
# 24       XRPBUSD   112034.20   112034.20        0.00       116740.00
# 25      DOGEBUSD   503127.00   503127.00        0.00       112080.00
# 26       XRPUSDT  -173082.20  -173082.20        0.00      -180248.00
# 27       AXSUSDT    -5809.00    -5809.00        0.00      -648418.00
# 💰ClickHereNow 2021-10-02 02:01:00
# Position change from -179.97BNBUSDT to -130.5BNBUSDT.
# BUY 49.47BNBUSDT at 420.8182$
# Trade went from-0.002% to -0.001% (BUY 0.001%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:01:03
# Position change from -329.316ETHUSDT to -330.306ETHUSDT.
# SELL 0.99ETHUSDT at 3310.9073$
# Trade went from-0.003% to -0.003% (SELL 0.0%)
# Status:OPEN
# 💰ClickHereNow 2021-10-02 02:01:05
# Position change from -198441.0TRXUSDT to -138717.0TRXUSDT.
# BUY 59724.0TRXUSDT at 0.0948$
# Trade went from-1.824% to -1.275% (BUY 0.549%)
# Status:OPEN

# %%
do_query(query="select MAX(id) as id from positions")["id"][0]

# %%
do_query(query=f"select distinct(request_id) from POSITIONS where encryptedUid = '{trader}' order by request_id desc limit 2")

# %%
do_query(query="select*from positions where nick='ClickHereNow'")
